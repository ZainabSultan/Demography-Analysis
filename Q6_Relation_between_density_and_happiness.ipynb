# %% [markdown]
# How does density affect happiness? Density is population divided by area and it represents how much a country is packed

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Readinf the data set

# %%
root_path_Integrated='Integrated_Data/'
Inegrated_data = pd.read_csv(root_path_Integrated+'Integrated_Happiness_Country_Data.csv')

# %% [markdown]
# plotting the relation between the happiness rank and the density

# %%
plt.figure(figsize=(20, 10))
l=pd.DataFrame(data = ["0-400" ,"400-800" ,"800-1200" , "1200-1600","1600-2000" , "2000-2400","2400-2800", "2800-3200" , "3200-3600", "3600-4000","4000-4400" ,"4400-4800",
                        "4800-5200" , "5200-5600" ,
                        "5600-6000" ,"6000-6400", "6400-6800", "6800-7200","7200-7600"  , "7600-8000"], columns = ["density_group"])
l= pd.merge(Inegrated_data[['Happiness Score','density_group']], l, how='right')
l['Happiness Score'].replace(np.nan,0 , inplace=True)
plt.bar( l["density_group"],l['Happiness Score'])
# plt.legend(loc=1)
Inegrated_data
# Out:
#      Unnamed: 0  index                   Country  Happiness Rank  \
# 0             0      0               Switzerland               1
# 1             1      1                   Iceland               2
# 2             2      2                   Denmark               3
# 3             3      3                    Norway               4
# 4             4      4                    Canada               5
# ..          ...    ...                       ...             ...
# 757         758    144                     Yemen             151
# 758         759    145                    Rwanda             152
# 759         760    146                  Tanzania             153
# 760         761    147               Afghanistan             154
# 761         762    148  Central African Republic             155
#
#      Happiness Score  Economy (GDP per Capita)  Social support  \
# 0              7.587                   1.39651         1.34951
# 1              7.561                   1.30232         1.40223
# 2              7.527                   1.32548         1.36058
# 3              7.522                   1.45900         1.33095
# 4              7.427                   1.32629         1.32261
# ..               ...                       ...             ...
# 757            3.380                   0.28700         1.16300
# 758            3.334                   0.35900         0.71100
# 759            3.231                   0.47600         0.88500
# 760            3.203                   0.35000         0.51700
# 761            3.083                   0.02600         1.42700
#
#      Healthy life expectancy  Freedom to make life choices  \
# 0                    0.94143                       0.66557
# 1                    0.94784                       0.62877
# 2                    0.87464                       0.64938
# 3                    0.88521                       0.66973
# 4                    0.90563                       0.63297
# ..                       ...                           ...
# 757                  0.46300                       0.14300
# 758                  0.61400                       0.55500
# 759                  0.49900                       0.41700
# 760                  0.36100                       0.00000
# 761                  0.10500                       0.22500
#
#      Trust (Government Corruption)  Generosity  Cluster  Year    region  \
# 0                          0.41978     0.29678        2  2015    Europe
# 1                          0.14145     0.43630        2  2015    Europe
# 2                          0.48357     0.34139        2  2015    Europe
# 3                          0.36503     0.34699        2  2015    Europe
# 4                          0.32957     0.45811        2  2015  Americas
# ..                             ...         ...      ...   ...       ...
# 757                        0.07700     0.10800        0  2019      Asia
# 758                        0.17200     0.21700        0  2019    Africa
# 759                        0.14700     0.27600        0  2019    Africa
# 760                        0.02500     0.15800        0  2019      Asia
# 761                        0.03500     0.23500        0  2019    Africa
#
#             subregion  population       area density_group
# 0      Western Europe   8341600.0    41284.0         0-400
# 1     Northern Europe    334300.0   103000.0         0-400
# 2     Northern Europe   5717014.0    43094.0         0-400
# 3     Northern Europe   5223256.0   323802.0         0-400
# 4    Northern America  36155487.0  9984670.0         0-400
# ..                ...         ...        ...           ...
# 757      Western Asia  27478000.0   527968.0         0-400
# 758    Eastern Africa  11553188.0    26338.0       400-800
# 759    Central Africa  56320000.0   945087.0         0-400
# 760     Southern Asia  27657145.0   652230.0         0-400
# 761     Middle Africa   4998000.0   622984.0         0-400
#
# [762 rows x 18 columns]

# %% [markdown]
# As we see in the figure above there's no relation between the density and the Happiness Score.
# And that's reasonable as it depends on how the country can make use of its area, and there population.
# the population could be human resources or a burden.
# also the landarea, The country can make good use of its area.
# So we conclude that there's no relation between the density and the happiness ranks
